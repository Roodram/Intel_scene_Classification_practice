# %%
import keras
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# %%
model = load_model("Models/Model_CNN6layer_new_e6.h5")

# %%
X_test = np.load("Data/X_test.npy")
Y_test_oh = np.load("Data/Y_test.npy")

# %%
plt.imshow(X_test[26,:,:,:])
plt.show()
print(Y_test_oh[26])
# Out:
# [0. 0. 0. 0. 0. 1.]

# %%
history = model.evaluate(X_test, Y_test_oh)
# Out:
# 3000/3000 [==============================] - 111s 37ms/step

# %%
print(history)
# Out:
# [1.2832882512410482, 0.5576666666666666]
